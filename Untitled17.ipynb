# %%
from google.colab import files
uploaded=files.upload()
import pandas as pd
df=pd.read_csv('index_cleaned.csv')
df.head()
#to create a time series analyis
df['datetime']=pd.to_datetime(df['datetime'],errors='coerce')
#monthly trends
monthly_trends=df.resample('M',on='datetime')['money'].sum()
#converting money into numerical
df['money']=pd.to_numeric(df['money'],errors='coerce')
#plotting time series graph of monthly rends
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,6))
sns.lineplot(x=monthly_trends.index,y=monthly_trends.values,marker='o')
plt.title('Monthly Trends')
plt.xlabel('date')
plt.ylabel('money')
plt.grid(True)
plt.show()
#daily trends
hourly_trends=df.groupby(df['datetime'].dt.hour)['money'].sum()
#hourly trend
plt.figure(figsize=(14,6))
sns.lineplot(x=hourly_trends.index,y=hourly_trends.values,marker='o')
plt.title('hourly')
plt.xlabel('date')
plt.ylabel('money')
plt.grid(True)
plt.show()
#daily_trend
daily_trend=df.groupby(df['datetime'].dt.date)['money'].sum()
plt.figure(figsize=(14,6))
sns.lineplot(x=daily_trend.index,y=daily_trend.values,marker='o')
plt.title('Daily Trends')
plt.xlabel('date')
plt.ylabel('money')
plt.grid(True)
plt.show()
#weekly
weekly_=df.groupby(df['datetime'].dt.dayofweek)['money'].sum()
plt.figure(figsize=(14,6))
sns.lineplot(x=weekly_.index,y=weekly_.values,marker='o')
plt.title('Weekly Trends')
plt.xlabel('date')
plt.ylabel('money')
plt.grid(True)
#ml model
# Feature engineering: Extract time features
df['hour'] = df['datetime'].dt.hour
df['dayofweek'] = df['datetime'].dt.dayofweek
df.head(10)

#spilliting into x and y
x=df[['card','hour','dayofweek','coffee_name']]
y=df['money']
#converting categorical value to numericals
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
categorical_features=['card','coffee_name']
preprocessor=ColumnTransformer([('cat',OneHotEncoder(),categorical_features)], remainder='passthrough')
#train test spilt
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
#transforming pre processor
# Transform features
from sklearn.pipeline import Pipeline
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])


#import model
from sklearn.linear_model import LinearRegression
pipeline.fit(x_train,y_train)
#predict
y_pred=pipeline.predict(x_test)
#evaluation
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
#      <input type="file" id="files-de4449eb-39dc-4738-8fd0-ec1cdd282e27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de4449eb-39dc-4738-8fd0-ec1cdd282e27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
